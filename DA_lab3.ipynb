# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.special import expit

# %%
data_norm = {'M,V (0, 0.01)': np.random.normal(0, 0.1, 10000), 'M,V (10, 100)':np.random.normal(10, 10, 10000), 'M,V (0, 1)':np.random.normal(0, 1, 10000),'M,V (50, 25)':np.random.normal(50, 5, 10000) }
df_norm = pd.DataFrame(data = data_norm)
data_log = {'M,V (0, 0.01)': expit(np.random.normal(0, 0.1, 10000)), 'M,V (10, 100)':expit(np.random.normal(10, 10, 10000)), 'M,V (0, 1)':expit(np.random.normal(0, 1, 10000)),'M,V (50, 25)':expit(np.random.normal(50, 5, 10000))}
df_log = pd.DataFrame(data = data_log)
data_pois = {'L (0.1)': np.random.poisson(0.1, 10000), 'L (1)': np.random.poisson(1, 10000), 'L (5)': np.random.poisson(5, 10000),'L (50)': np.random.poisson(50, 10000) }
df_pois = pd.DataFrame(data = data_pois)
data_beta = {'A,B (1, 1)': np.random.beta(1, 1, 10000), 'A,B (1, 100)': np.random.beta(1, 100, 10000), 'A,B (100, 1)': np.random.beta(10, 1, 10000),'A,B (10, 100)': np.random.beta(10, 100, 10000)}
df_beta = pd.DataFrame(data = data_beta)
data_log_norm = {'M,V (0, 0.01)': np.random.lognormal(0, 0.1, 10000), 'M,V (10, 100)':np.random.lognormal(10, 10, 10000), 'M,V (0, 1)':np.random.lognormal(0, 1, 10000),'M,V (50, 25)':np.random.lognormal(50, 5, 10000) }
df_log_norm = pd.DataFrame(data = data_norm)

# %%
def plot_non_cumulative(df):
    melted = pd.melt(df)
    g1 = sns.FacetGrid(melted, col = "variable", sharex = True, sharey = False)
    g1 = g1.map(plt.hist, 'value', density = True, cumulative = False, bins = 20)

# %%
def plot_cumulative(df):
    melted = pd.melt(df)
    g2 = sns.FacetGrid(melted, col = "variable", sharex = True, sharey = False)
    g2 = g2.map(plt.hist, 'value', density = True, cumulative = True, bins = 20)

# %%
df_log.head()
# Out:
#    M,V (0, 0.01)  M,V (10, 100)  M,V (0, 1)  M,V (50, 25)
# 0       0.514691       0.998614    0.502046           1.0
# 1       0.493596       0.990107    0.469440           1.0
# 2       0.493269       0.952730    0.277224           1.0
# 3       0.529803       0.999783    0.492419           1.0
# 4       0.507360       1.000000    0.533285           1.0

# %%
df_log.tail()
# Out:
#       M,V (0, 0.01)  M,V (10, 100)  M,V (0, 1)  M,V (50, 25)
# 9995       0.474329       0.000047    0.427115           1.0
# 9996       0.491260       1.000000    0.567112           1.0
# 9997       0.485765       0.999952    0.590934           1.0
# 9998       0.529976       0.020921    0.296736           1.0
# 9999       0.511995       0.999942    0.678079           1.0

# %% [markdown]
# # Normal

# %%
plot_non_cumulative(df_norm)

# %%
plot_cumulative(df_norm)

# %% [markdown]
# # Logit

# %%
plot_non_cumulative(df_log)

# %%
plot_cumulative(df_log)

# %% [markdown]
# # Poisson

# %%
plot_non_cumulative(df_pois)

# %%
plot_cumulative(df_pois)

# %% [markdown]
# # Beta

# %%
plot_non_cumulative(df_beta)

# %%
plot_cumulative(df_beta)

# %% [markdown]
# # Log normal

# %%
plot_non_cumulative(df_log_norm)

# %%
plot_cumulative(df_log_norm)
